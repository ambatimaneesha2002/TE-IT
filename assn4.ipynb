# %%
import pandas as pd

# %%
data= pd.read_csv("newfb.csv")

# %%
data.head(20)
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             136013  Status         2          10             5          3
# 1             136013   Photo         1          10             4         10
# 2             136013    Link         1          10             4          3
# 3             136013  Status         3          10             3         10
# 4             136013  Status         2          10             3          2
# 5             136013   Photo         3          10             2         10
# 6             136013   Photo         1          10             2          3
# 7             136013   Photo         1          10             1         10
# 8             136013   Photo         3          10             1          3
# 9             135713   Photo         3          10             7         10
# 10            135713  Status         2          10             7          4
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.iloc[2:10,:]
#10th row excluded
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 2            136013    Link         1          10             4          3
# 3            136013  Status         3          10             3         10
# 4            136013  Status         2          10             3          2
# 5            136013   Photo         3          10             2         10
# 6            136013   Photo         1          10             2          3
# 7            136013   Photo         1          10             1         10
# 8            136013   Photo         3          10             1          3
# 9            135713   Photo         3          10             7         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 2     0                      68992                           229733
# 3     0                      13152                            25666
# 4     1                      31136                            59964
# ...

# %%
data.shape
# Out:
# (134, 19)

# %%
data.iloc[2:10,4]
# Out:
# 2    4
# 3    3
# 4    3
# 5    2
# 6    2
# 7    1
# 8    1
# 9    7
# Name: Post Weekday, dtype: int64

# %%
data.iloc[:7,9:]
# Out:
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                    1480                     1426
# 1                     428                      374
# 2                    1032                      975
# 3                    2543                     2438
# 4                    6164                     5934
# 5                     714                      440
# 6                    1462                     1450
#
#    Lifetime Post Consumptions  \
# 0                        1932
# 1                         616
# 2                        1345
# 3                        3179
# 4                        9237
# 5                         720
# 6                        8308
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                              13838
# 1                                               6677
# 2                                              17842
# 3                                              20547
# ...

# %%
data.iloc[[0,3,5,4],[3,2,5]]
# Out:
#    Post Month  Category  Post Hour
# 0          10         2          3
# 3          10         3         10
# 5          10         3         10
# 4          10         2          2

# %%
data.iloc[-10:-1,1:-10]
# Out:
#        Type  Category  Post Month  Post Weekday  Post Hour  Paid  \
# 124   Photo         2           7             1          3     0
# 125   Photo         2           7             7         11     1
# 126   Photo         3           7             7          3     0
# 127   Photo         3           7             6         13     1
# 128   Photo         1           7             6          3     0
# 129  Status         2           7             5         10     0
# 130   Photo         1           7             5          3     0
# 131   Photo         1           7             4          9     1
# 132   Photo         2           7             4          5     1
#
#      Lifetime Post Total Reach  Lifetime Post Total Impressions
# 124                       3330                             5461
# 125                       3528                             5918
# 126                      38576                            55398
# ...

# %%
data.loc[[1,2,5,6,7],'Category':'Paid']
# Out:
#    Category  Post Month  Post Weekday  Post Hour  Paid
# 1         1          10             4         10     1
# 2         1          10             4          3     0
# 5         3          10             2         10     1
# 6         1          10             2          3     1
# 7         1          10             1         10     1

# %%
data.loc[[1,2,5,6,7],:'Paid']
# Out:
#    Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 1            136013  Photo         1          10             4         10
# 2            136013   Link         1          10             4          3
# 5            136013  Photo         3          10             2         10
# 6            136013  Photo         1          10             2          3
# 7            136013  Photo         1          10             1         10
#
#    Paid
# 1     1
# 2     0
# 5     1
# 6     1
# 7     1

# %%
Z=data.loc[[1,2,3,6,5,7,89,34,23],'Type':]
Z=Z[Z['comment']>6];
Z
# Out:
#       Type  Category  Post Month  Post Weekday  Post Hour  Paid  \
# 2     Link         1          10             4          3     0
# 5    Photo         3          10             2         10     1
# 34  Status         2           9             1         10     0
#
#     Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 2                       68992                           229733
# 5                       16776                            39549
# 34                      21256                            41906
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# 2                     1032                      975
# 5                      714                      440
# 34                    4840                     4754
#
#     Lifetime Post Consumptions  \
# 2                         1345
# 5                          720
# 34                        5906
#
#     Lifetime Post Impressions by people who have liked your Page  \
# ...

# %%
Z.shape
# Out:
# (6, 19)

# %%
Y=Z.melt(id_vars=['Type','Paid'])
Y
# Out:
#        Type  Paid            variable     value
# 0      Link     0    Page total likes  136013.0
# 1    Status     0    Page total likes  136013.0
# 2     Photo     1    Page total likes  136013.0
# 3     Photo     1    Page total likes  131728.0
# 4    Status     0    Page total likes  135195.0
# ..      ...   ...                 ...       ...
# 97   Status     0  Total Interactions     265.0
# 98    Photo     1  Total Interactions     447.0
# 99    Photo     1  Total Interactions     126.0
# 100  Status     0  Total Interactions     228.0
# 101   Photo     0  Total Interactions     282.0
#
# [102 rows x 4 columns]

# %%
X=pd.get_dummies(Y)
X
# Out:
#      Paid     value  Type_Link  Type_Photo  Type_Status  variable_Category  \
# 0       0  136013.0       True       False        False              False
# 1       0  136013.0      False       False         True              False
# 2       1  136013.0      False        True        False              False
# 3       1  131728.0      False        True        False              False
# 4       0  135195.0      False       False         True              False
# ..    ...       ...        ...         ...          ...                ...
# 97      0     265.0      False       False         True              False
# 98      1     447.0      False        True        False              False
# 99      1     126.0      False        True        False              False
# 100     0     228.0      False       False         True              False
# 101     0     282.0      False        True        False              False
#
#      variable_Lifetime Engaged Users  \
# ...

# %%
Z.to_csv('output_z.csv',index=False)

# %%
Z.to_json('output_z.json')

# %%
Y.to_html('melting_output')

# %%
data1=pd.read_csv('fb.csv')

# %%
data1.shape
# Out:
# (500, 19)

# %%
data.shape
# Out:
# (134, 19)

# %%
merged_data=pd.concat([data1,data])

# %%
merged_data.shape
# Out:
# (634, 19)

# %%
merged_data.drop(['Type','Paid'],axis=1)
# Out:
#      Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441         2          12             4          3
# 1              139441         2          12             3         10
# 2              139441         3          12             3          3
# 3              139441         2          12             2         10
# 4              139441         2          12             2          3
# ..                ...       ...         ...           ...        ...
# 129            128032         2           7             5         10
# 130            128032         1           7             5          3
# 131            128032         1           7             4          9
# 132            128032         2           7             4          5
# 133            128032         1           7             3         10
#
#      Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0                         2752                             5091
# ...

# %%
X_data=[]
X_data.extend(range(2,10))
X_data.extend(range(2,10))

# %%
data.iloc[X_data,4:7]
# Out:
#    Post Weekday  Post Hour  Paid
# 2             4          3     0
# 3             3         10     0
# 4             3          2     1
# 5             2         10     1
# 6             2          3     1
# 7             1         10     1
# 8             1          3     0
# 9             7         10     0
# 2             4          3     0
# 3             3         10     0
# 4             3          2     1
# 5             2         10     1
# 6             2          3     1
# 7             1         10     1
# 8             1          3     0
# 9             7         10     0
